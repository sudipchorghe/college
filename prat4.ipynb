# %%
marks = []

while True:
    print("\n--- Student Management System ---")
    print("1. Enter student marks")
    print("2. Display all marks")
    print("3. Total and Average marks")
    print("4. Highest and Lowest marks")
    print("5. Passed and Failed students")
    print("6. Distinction students (>=75)")
    print("7. Remove duplicate marks")
    print("8. Replace failed marks with grace (40)")
    print("9. Search a mark")
    print("10. Sort marks & reverse")
    print("11. Remove a student record")
    print("12. Find position of a mark")
    print("13. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        n = int(input("How many students? "))
        for i in range(n):
            m = int(input("Enter mark: "))
            marks.append(m)

    elif choice == 2:
        print("Student Marks:", marks)

    elif choice == 3:
        if len(marks) > 0:
            total = sum(marks)
            avg = total / len(marks)
            print("Total =", total)
            print("Average =", avg)
        else:
            print("No marks available")

    elif choice == 4:
        if len(marks) > 0:
            print("Highest =", max(marks))
            print("Lowest =", min(marks))
        else:
            print("No marks available")

    elif choice == 5:
        passed = []
        failed = []
        for m in marks:
            if m >= 40:
                passed.append(m)
            else:
                failed.append(m)
        print("Passed students:", passed)
        print("Failed students:", failed)

    elif choice == 6:
        distinction = []
        for m in marks:
            if m >= 75:
                distinction.append(m)
        print("Distinction students:", distinction)

    elif choice == 7:
        marks = list(set(marks))
        print("Duplicates removed:", marks)

    elif choice == 8:
        for i in range(len(marks)):
            if marks[i] < 40:
                marks[i] = 40
        print("Grace marks applied:", marks)

    elif choice == 9:
        s = int(input("Enter mark to search: "))
        if s in marks:
            print("Mark found")
        else:
            print("Mark not found")

    elif choice == 10:
        marks.sort()
        print("Sorted marks:", marks)
        print("Reverse order:", marks[::-1])

    elif choice == 11:
        r = int(input("Enter mark to remove: "))
        if r in marks:
            marks.remove(r)
            print("Record removed")
        else:
            print("Mark not found")

    elif choice == 12:
        p = int(input("Enter mark: "))
        if p in marks:
            print("Position (index):", marks.index(p))
        else:
            print("Mark not found")

    elif choice == 13:
        print("Exiting program...")
        break

    else:
        print("Invalid choice")
# Out:
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  1
# How many students?  5
# Enter mark:  12
# Enter mark:  12
# Enter mark:  13
# Enter mark:  14
# Enter mark:  15
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  2
# Student Marks: [12, 12, 13, 14, 15]
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  3
# Total = 66
# Average = 13.2
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  4
# Highest = 15
# Lowest = 12
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  5
# Passed students: []
# Failed students: [12, 12, 13, 14, 15]
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  6
# Distinction students: []
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  7
# Duplicates removed: [12, 13, 14, 15]
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  8
# Grace marks applied: [40, 40, 40, 40]
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# Enter your choice:  9
# Enter mark to search:  12
# Mark not found
#
# --- Student Management System ---
# 1. Enter student marks
# 2. Display all marks
# 3. Total and Average marks
# 4. Highest and Lowest marks
# 5. Passed and Failed students
# 6. Distinction students (>=75)
# 7. Remove duplicate marks
# 8. Replace failed marks with grace (40)
# 9. Search a mark
# 10. Sort marks & reverse
# 11. Remove a student record
# 12. Find position of a mark
# 13. Exit
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 19
#      16 print("12. Find position of a mark")
#      17 print("13. Exit")
# ---> 19 choice = int(input("Enter your choice: "))
#      21 if choice == 1:
#      22     n = int(input("How many students? "))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
